# %%
import pandas as pd
import os
logs = pd.read_csv(os.path.join("Fortinet_201811.csv"),low_memory=False)

# %%
logs = logs[:1000]
logs.head()
# Out:
#                 Event Time             Receipt Time  \
# 0  2018/11/01 00:00:01 CST  2018/11/01 00:00:05 CST
# 1  2018/11/01 00:00:01 CST  2018/11/01 00:00:05 CST
# 2  2018/11/01 00:00:01 CST  2018/11/01 00:00:05 CST
# 3  2018/11/01 00:00:01 CST  2018/11/01 00:00:05 CST
# 4  2018/11/01 00:00:01 CST  2018/11/01 00:00:05 CST
#
#                        Device Logger  Version Device Vendor Device Product  \
# 0  10.0.4.167 [Center_Syslog]     本機        0      Fortinet      Fortigate
# 1  10.0.4.167 [Center_Syslog]     本機        0      Fortinet      Fortigate
# 2  10.0.4.167 [Center_Syslog]     本機        0      Fortinet      Fortigate
# 3  10.0.4.167 [Center_Syslog]     本機        0      Fortinet      Fortigate
# 4  10.0.4.167 [Center_Syslog]     本機        0      Fortinet      Fortigate
#
#    Device Version  deviceEventClassId              Name     ...       \
# 0             NaN                  13  traffic: forward     ...
# ...

# %%
logs.shape
# Out:
# (1000, 134)

# %%
logs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Columns: 134 entries, Event Time to ad.authproto
# dtypes: float64(34), int64(4), object(96)
# memory usage: 1.0+ MB

# %%
logs["Logger"].value_counts()
# Out:
# 本機    1000
# Name: Logger, dtype: int64

# %%
logs.describe()
# Out:
#        Version  Device Version  deviceEventClassId  Non-CEF Raw Message  \
# count   1000.0             0.0         1000.000000                  0.0
# mean       0.0             NaN          653.186000                  NaN
# std        0.0             NaN         4483.673224                  NaN
# min        0.0             NaN           11.000000                  NaN
# 25%        0.0             NaN           13.000000                  NaN
# 50%        0.0             NaN           13.000000                  NaN
# 75%        0.0             NaN           13.000000                  NaN
# max        0.0             NaN        32038.000000                  NaN
#
#        destinationTranslatedPort    sourcePort       eventId    ad.craction  \
# count                 292.000000    903.000000  1.000000e+03     241.000000
# mean                14686.297945  49975.895903  1.637421e+08  139773.875519
# std                 13815.488497  14142.770237  3.073003e+02   32699.945929
# ...

# %%
logs.loc[990]
# Out:
# Event Time                                                2018/11/01 00:00:06 CST
# Receipt Time                                              2018/11/01 00:00:07 CST
# Device                                                 10.0.4.167 [Center_Syslog]
# Logger                                                                         本機
# Version                                                                         0
# Device Vendor                                                            Fortinet
# Device Product                                                          Fortigate
# Device Version                                                                NaN
# deviceEventClassId                                                             13
# Name                                                             traffic: forward
# Severity                                                                      Low
# ...
